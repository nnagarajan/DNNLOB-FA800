# %%
#%%bash
#!/bin/bash
#conda env list
#pwd

# %%
# %%bash
# #!/bin/bash
# DTM=`date`
# nohup papermill scheduler-test.ipynb scheduler-test-out.ipynb > scheduler-test.log &
# Out:
# /home/nnagara1/miniconda3/envs/fa800/lib/python3.12/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# Input Notebook:  scheduler-test.ipynb
# Output Notebook: scheduler-test-out.ipynb
# ...
# Executing: 100%|██████████| 3/3 [00:07<00:00,  2.65s/cell]

# %%
# %%bash
# #!/bin/bash
# DTM=`date`
# #nohup papermill scheduler.ipynb scheduler-out.ipynb > scheduler-out.log &
