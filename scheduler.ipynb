# %%
##%%bash
#!/bin/bash
#conda env list
#pwd

# %%
import papermill as pm
import os
JPY_ITER_NO=1
JPY_ALPHA=0.01
JPY_HORIZON=2
JPY_TICKERS="slv"
os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
pm.execute_notebook(
   'experiments.ipynb',
   f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
   parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO,horizon_to_predict=JPY_HORIZON,tickers=JPY_TICKERS)
)

# %%
import papermill as pm
import os
JPY_ITER_NO=2
JPY_ALPHA=0.02
JPY_HORIZON=2
JPY_TICKERS="slv"
os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
pm.execute_notebook(
   'experiments.ipynb',
   f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
   parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO,horizon_to_predict=JPY_HORIZON,tickers=JPY_TICKERS)
)

# %%
# import papermill as pm
# import os
# JPY_ITER_NO=3
# JPY_ALPHA=0.03
# JPY_HORIZON=2
# JPY_TICKERS="slv"
# os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
# pm.execute_notebook(
#    'experiments.ipynb',
#    f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
#    parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO,horizon_to_predict=JPY_HORIZON,tickers=JPY_TICKERS)
# )

# %%
import papermill as pm
import os
JPY_ITER_NO=4
JPY_ALPHA=0.01
JPY_HORIZON=2
JPY_TICKERS="gdx"
os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
pm.execute_notebook(
   'experiments.ipynb',
   f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
   parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO,horizon_to_predict=JPY_HORIZON,tickers=JPY_TICKERS)
)

# %%
import papermill as pm
import os
JPY_ITER_NO=5
JPY_ALPHA=0.02
JPY_HORIZON=2
JPY_TICKERS="gdx"
os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
pm.execute_notebook(
   'experiments.ipynb',
   f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
   parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO,horizon_to_predict=JPY_HORIZON,tickers=JPY_TICKERS)
)

# %%
# import papermill as pm
# import os
# JPY_ITER_NO=6
# JPY_ALPHA=0.03
# JPY_HORIZON=2
# JPY_TICKERS="gdx"
# os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
# pm.execute_notebook(
#    'experiments.ipynb',
#    f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
#    parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO,horizon_to_predict=JPY_HORIZON,tickers=JPY_TICKERS)
# )

# %%
import papermill as pm
import os
JPY_ITER_NO=7
JPY_ALPHA=0.01
JPY_HORIZON=2
JPY_TICKERS="soxs"
os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
pm.execute_notebook(
   'experiments.ipynb',
   f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
   parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO,horizon_to_predict=JPY_HORIZON,tickers=JPY_TICKERS)
)

# %%
import papermill as pm
import os
JPY_ITER_NO=8
JPY_ALPHA=0.02
JPY_HORIZON=2
JPY_TICKERS="soxs"
os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
pm.execute_notebook(
   'experiments.ipynb',
   f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
   parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO,horizon_to_predict=JPY_HORIZON,tickers=JPY_TICKERS)
)

# %%
# import papermill as pm
# import os
# JPY_ITER_NO=9
# JPY_ALPHA=0.03
# JPY_HORIZON=2
# JPY_TICKERS="soxs"
# os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
# pm.execute_notebook(
#    'experiments.ipynb',
#    f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
#    parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO,horizon_to_predict=JPY_HORIZON,tickers=JPY_TICKERS)
# )

# %%
import papermill as pm
import os
JPY_ITER_NO=10
JPY_ALPHA=0.01
JPY_HORIZON=1
JPY_TICKERS="slv"
os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
pm.execute_notebook(
   'experiments.ipynb',
   f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
   parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO,horizon_to_predict=JPY_HORIZON,tickers=JPY_TICKERS)
)

# %%
import papermill as pm
import os
JPY_ITER_NO=11
JPY_ALPHA=0.02
JPY_HORIZON=1
JPY_TICKERS="slv"
os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
pm.execute_notebook(
   'experiments.ipynb',
   f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
   parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO,horizon_to_predict=JPY_HORIZON,tickers=JPY_TICKERS)
)

# %%
# import papermill as pm
# import os
# JPY_ITER_NO=12
# JPY_ALPHA=0.03
# JPY_HORIZON=1
# JPY_TICKERS="slv"
# os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
# pm.execute_notebook(
#    'experiments.ipynb',
#    f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
#    parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO,horizon_to_predict=JPY_HORIZON,tickers=JPY_TICKERS)
# )

# %%
import papermill as pm
import os
JPY_ITER_NO=13
JPY_ALPHA=0.01
JPY_HORIZON=1
JPY_TICKERS="gdx"
os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
pm.execute_notebook(
   'experiments.ipynb',
   f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
   parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO,horizon_to_predict=JPY_HORIZON,tickers=JPY_TICKERS)
)

# %%
import papermill as pm
import os
JPY_ITER_NO=14
JPY_ALPHA=0.02
JPY_HORIZON=1
JPY_TICKERS="gdx"
os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
pm.execute_notebook(
   'experiments.ipynb',
   f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
   parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO,horizon_to_predict=JPY_HORIZON,tickers=JPY_TICKERS)
)

# %%
# import papermill as pm
# import os
# JPY_ITER_NO=15
# JPY_ALPHA=0.03
# JPY_HORIZON=1
# JPY_TICKERS="gdx"
# os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
# pm.execute_notebook(
#    'experiments.ipynb',
#    f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
#    parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO,horizon_to_predict=JPY_HORIZON,tickers=JPY_TICKERS)
# )

# %%
import papermill as pm
import os
JPY_ITER_NO=16
JPY_ALPHA=0.01
JPY_HORIZON=1
JPY_TICKERS="soxs"
os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
pm.execute_notebook(
   'experiments.ipynb',
   f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
   parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO,horizon_to_predict=JPY_HORIZON,tickers=JPY_TICKERS)
)

# %%
import papermill as pm
import os
JPY_ITER_NO=17
JPY_ALPHA=0.02
JPY_HORIZON=1
JPY_TICKERS="soxs"
os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
pm.execute_notebook(
   'experiments.ipynb',
   f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
   parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO,horizon_to_predict=JPY_HORIZON,tickers=JPY_TICKERS)
)

# %%
# import papermill as pm
# import os
# JPY_ITER_NO=18
# JPY_ALPHA=0.03
# JPY_HORIZON=1
# JPY_TICKERS="soxs"
# os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
# pm.execute_notebook(
#    'experiments.ipynb',
#    f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
#    parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO,horizon_to_predict=JPY_HORIZON,tickers=JPY_TICKERS)
# )

# %%
import papermill as pm
import os

JPY_ITER_NO = 19
JPY_ALPHA = 0.01
JPY_HORIZON = 0
JPY_TICKERS = "slv"
os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
pm.execute_notebook(
   'experiments.ipynb',
   f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
   parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO, horizon_to_predict=JPY_HORIZON, tickers=JPY_TICKERS)
)

# %%
import papermill as pm
import os

JPY_ITER_NO = 20
JPY_ALPHA = 0.02
JPY_HORIZON = 0
JPY_TICKERS = "slv"
os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
pm.execute_notebook(
   'experiments.ipynb',
   f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
   parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO, horizon_to_predict=JPY_HORIZON, tickers=JPY_TICKERS)
)

# %%
# import papermill as pm
# import os
#
# JPY_ITER_NO = 21
# JPY_ALPHA = 0.03
# JPY_HORIZON = 0
# JPY_TICKERS = "slv"
# os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
# pm.execute_notebook(
#    'experiments.ipynb',
#    f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
#    parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO, horizon_to_predict=JPY_HORIZON, tickers=JPY_TICKERS)
# )

# %%
import papermill as pm
import os

JPY_ITER_NO = 22
JPY_ALPHA = 0.01
JPY_HORIZON = 0
JPY_TICKERS = "gdx"
os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
pm.execute_notebook(
   'experiments.ipynb',
   f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
   parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO, horizon_to_predict=JPY_HORIZON, tickers=JPY_TICKERS)
)

# %%
import papermill as pm
import os

JPY_ITER_NO = 23
JPY_ALPHA = 0.02
JPY_HORIZON = 0
JPY_TICKERS = "gdx"
os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
pm.execute_notebook(
   'experiments.ipynb',
   f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
   parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO, horizon_to_predict=JPY_HORIZON, tickers=JPY_TICKERS)
)

# %%
# import papermill as pm
# import os
#
# JPY_ITER_NO = 24
# JPY_ALPHA = 0.03
# JPY_HORIZON = 0
# JPY_TICKERS = "gdx"
# os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
# pm.execute_notebook(
#    'experiments.ipynb',
#    f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
#    parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO, horizon_to_predict=JPY_HORIZON, tickers=JPY_TICKERS)
# )

# %%
import papermill as pm
import os

JPY_ITER_NO = 25
JPY_ALPHA = 0.01
JPY_HORIZON = 0
JPY_TICKERS = "soxs"
os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
pm.execute_notebook(
   'experiments.ipynb',
   f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
   parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO, horizon_to_predict=JPY_HORIZON, tickers=JPY_TICKERS)
)

# %%
import papermill as pm
import os

JPY_ITER_NO = 26
JPY_ALPHA = 0.02
JPY_HORIZON = 0
JPY_TICKERS = "soxs"
os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
pm.execute_notebook(
   'experiments.ipynb',
   f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
   parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO, horizon_to_predict=JPY_HORIZON, tickers=JPY_TICKERS)
)

# %%
# import papermill as pm
# import os
#
# JPY_ITER_NO = 27
# JPY_ALPHA = 0.03
# JPY_HORIZON = 0
# JPY_TICKERS = "soxs"
# os.makedirs(f"results2/iteration{JPY_ITER_NO}", exist_ok=True)
# pm.execute_notebook(
#    'experiments.ipynb',
#    f"results2/iteration{JPY_ITER_NO}/experiments.ipynb",
#    parameters=dict(alpha=JPY_ALPHA, iteration_no=JPY_ITER_NO, horizon_to_predict=JPY_HORIZON, tickers=JPY_TICKERS)
# )
